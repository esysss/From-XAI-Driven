# %%
import dill
import pandas as pd

# %%
with open('subset_optimized_simple_size_0.2_fitnessweights_p0.34_f0.33_c0.33_weightmodel_weight_positive_simplified.pickle', "rb") as dill_file:
    data2 = dill.load(dill_file)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 with open('subset_optimized_simple_size_0.2_fitnessweights_p0.34_f0.33_c0.33_weightmodel_weight_positive_simplified.pickle', "rb") as dill_file:
# ----> 2     data2 = dill.load(dill_file)
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:289, in load(file, ignore, **kwds)
#     283 def load(file, ignore=None, **kwds):
#     284     """
#     285     Unpickle an object from a file.
#     286
#     287     See :func:`loads` for keyword arguments.
#     288     """
# --> 289     return Unpickler(file, ignore=ignore, **kwds).load()
#
# File ~\anaconda3\Lib\site-packages\dill\_dill.py:444, in Unpickler.load(self)
#     443 def load(self): #NOTE: if settings change, need to update attributes
# --> 444     obj = StockUnpickler.load(self)
# ...

# %%
df = pd.read_pickle('subset_optimized_simple_size_0.2_fitnessweights_p0.34_f0.33_c0.33_weightmodel_weight_positive_simplified.pickle')

# %%
df.head()
# Out:
#                                                     rule base_model_name  \
# index
# 29     [{'feature_abbrv': 'functstat', 'feature_value...              NN
# 439    [{'feature_abbrv': 'functstat', 'feature_value...             XGB
# 17     [{'feature_abbrv': 'functstat', 'feature_value...              NN
# 126    [{'feature_abbrv': 'functstat', 'feature_value...              NN
# 145    [{'feature_abbrv': 'functstat', 'feature_value...              NN
#
#       surrogate_name                             instance_mapping_train  \
# index
# 29              CART  [9, 28, 63, 66, 67, 89, 106, 131, 152, 224, 28...
# 439             CART  [9, 13, 38, 39, 53, 63, 66, 80, 91, 101, 106, ...
# 17              CART  [367, 592, 903, 906, 1556, 1840, 2273, 2443, 2...
# 126             CART  [2, 51, 116, 125, 140, 232, 512, 537, 563, 578...
# 145             CART  [181, 452, 539, 729, 756, 770, 1192, 1228, 129...
#
#                                    instance_mapping_test  \
# index
# ...
